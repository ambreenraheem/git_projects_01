# %% [markdown]
# ## **NAME: AMBREEN ABDULRAHEEM**
# ##  **SUBJECT: EXPLORATRY DATA ANALYSIS AND DATA WRANGLING**
# ##  **DATA NAME: PENGUINS**
# ##  **CONTACT: gmail.com**

# %% [markdown]
# ### **ABOUT DATA OF PENGUINS**
# **We're going to practice some Exploratry Data Analysis and Data Wrangling in python using data for penguin sizes recorded by Dr. Kristen Gorman and colleagues with the Palmer Station Long Term Ecological Research site (Palmer LTER) at several islands in the Palmer Archipelago, Antarctica. Data are originally published in: Gorman KB, Williams TD, Fraser WR (2014) PLoS ONE 9(3): e90081. doi:10.1371/journal.pone.0090081, and made available through the Environmental Data Initiative.**

# %% [markdown]
# **DATA VISUALISATION**\
# First import some important libraries.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Import the data set from seaborn libraries**

# %%
penguins=sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **Put your dataset in an other variable for safe side**

# %%
# just for saving it in the case of repeating data
pgsdata=penguins
pgsdata
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **Now visualise your data with some important steps of codes**

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# **bill_length_mm: This column contains measurements of the bill length of penguins in millimeters. Here are some key statistics:\
# Mean: The average bill length is approximately 43.92 mm.\
# Standard Deviation (std): The variation in bill length around the mean is approximately 5.46 mm.\
# Minimum: The smallest recorded bill length is 32.1 mm.\
# 25th Percentile (25%): 25% of the data falls below a bill length of 39.23 mm.\
# Median (50%): The middle value (50th percentile) is approximately 44.45 mm.\
# 75th Percentile (75%): 75% of the data falls below a bill length of 48.5 mm.\
# Maximum: The largest recorded bill length is 59.6 mm.\
# bill_depth_mm: This column represents the bill depth (width) of penguins in millimeters. The statistics follow a similar pattern as above.\
# flipper_length_mm: The flipper length refers to the length of a penguin’s flipper (wing) in millimeters. Key statistics include the mean, standard deviation, minimum, maximum, and quartiles.\
# body_mass_g: This column provides information about the body mass of penguins in grams. The mean body mass is approximately 4201.75 g, with variations around this value.\
# These statistics help us understand the distribution and variability of these penguin features. Keep in mind that these measurements are specific to the dataset you’re analyzing.**

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# # **To take unique value of whole data.**
# **The .nunique() function provides a count of unique values, which can be helpful for data exploration and analysis.**

# %%
penguins.nunique()
# Out:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# dtype: int64

# %% [markdown]
# # **After loading dataset save your data in EXCEL file**

# %%
penguins.to_excel('penguins.xlsx')

# %% [markdown]
# # **If you want to see the information about your data that, it is objective or numeric data**

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ## **.value_count()will tell you the total number sex (male and female) of penguins.**

# %%
penguins.sex.value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %% [markdown]
# ## **The descriptive statistics for the ‘penguins’ dataset after grouping it by both ‘sex’ and ‘island’,is actually showing you what different types of female and male penguins living in different islands.**

# %%
penguins.groupby(['sex','island']).describe().T
# Out:
# sex                           Female                                   Male  \
# island                        Biscoe        Dream    Torgersen       Biscoe
# bill_length_mm    count    80.000000    61.000000    24.000000    83.000000
#                   mean     43.307500    42.296721    37.554167    47.119277
#                   std       4.177631     5.533834     2.207887     4.691000
#                   min      34.500000    32.100000    33.500000    37.600000
#                   25%      39.675000    37.000000    35.850000    43.800000
#                   50%      44.900000    42.500000    37.600000    48.500000
#                   75%      46.500000    46.400000    39.125000    50.050000
#                   max      50.500000    58.000000    41.100000    59.600000
# bill_depth_mm     count    80.000000    61.000000    24.000000    83.000000
#                   mean     15.191250    17.601639    17.550000    16.597590
# ...

# %% [markdown]
# ## **This function of .count(),giving you 'penguins' in total number of population with grouping in 'species' and 'island'.**

# %%
penguins.groupby(["species","island"]).count()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   island
# Adelie    Biscoe                 44             44                 44
#           Dream                  56             56                 56
#           Torgersen              51             51                 51
# Chinstrap Dream                  68             68                 68
# Gentoo    Biscoe                123            123                123
#
#                      body_mass_g  sex
# species   island
# Adelie    Biscoe              44   44
#           Dream               56   55
#           Torgersen           51   47
# Chinstrap Dream               68   68
# Gentoo    Biscoe             123  119

# %% [markdown]
# # **NOW PLOT YOUR DATA IN JOINTPLOT**

# %%
# To analysis give it firt look by PLOT
penguins=sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")
penguins

# %% [markdown]
# # **Cleaning and Filtering Data**
# ## **If any thing is null in your data then it's better to remove because it could make problem for you.**
# ("Here you can see the 'sex' has more missibg values or you can say 'sex' has NaNs in many rows,so we have to drop it in next function.)

# %%
penguins.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 penguins.isnull().sum()
#
# AttributeError: 'JointGrid' object has no attribute 'isnull'

# %% [markdown]
# ## **Removing missing value column (sex) from data, we call it (cleaning of data)/ and give new variable name to this filtered data.**

# %%
pgdata1=penguins.drop(['sex'],axis=1)
pgdata1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g
# 0         3750.0
# 1         3800.0
# 2         3250.0
# 3            NaN
# ...

# %% [markdown]
# ## **To make sure that column is removed or not**
# Yes, one column of 'sex' and two rows of 'male' and 'female'..

# %%
pgdata1.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# dtype: int64

# %%
pgdata1.dropna().shape
# Out:
# (342, 6)

# %% [markdown]
# ## If you want to see only wanted columns. Use loc function.

# %%
pgdata1.loc[:20,["bill_length_mm","bill_depth_mm","flipper_length_mm"]]
# Out:
#     bill_length_mm  bill_depth_mm  flipper_length_mm
# 0             39.1           18.7              181.0
# 1             39.5           17.4              186.0
# 2             40.3           18.0              195.0
# 3              NaN            NaN                NaN
# 4             36.7           19.3              193.0
# 5             39.3           20.6              190.0
# 6             38.9           17.8              181.0
# 7             39.2           19.6              195.0
# 8             34.1           18.1              193.0
# 9             42.0           20.2              190.0
# 10            37.8           17.1              186.0
# 11            37.8           17.3              180.0
# 12            41.1           17.6              182.0
# 13            38.6           21.2              191.0
# 14            34.6           21.1              198.0
# 15            36.6           17.8              185.0
# 16            38.7           19.0              195.0
# ...

# %%
pgdata1.loc[:20,["body_mass_g"]]
# Out:
#     body_mass_g
# 0        3750.0
# 1        3800.0
# 2        3250.0
# 3           NaN
# 4        3450.0
# 5        3650.0
# 6        3625.0
# 7        4675.0
# 8        3475.0
# 9        4250.0
# 10       3300.0
# 11       3700.0
# 12       3200.0
# 13       3800.0
# 14       4400.0
# 15       3700.0
# 16       3450.0
# 17       4500.0
# 18       3325.0
# 19       4200.0
# 20       3400.0

# %% [markdown]
# ## **USING OF BOX PLOT FOR SHOWING BODY_MASS_G, SPECIES OF PENGUINS**.

# %% [markdown]
# ### **In x = axis, you can see the types of 'penguin' species with there names,and in Y=axis, you can see the weight of there body_mass in grams.**
# ### **The GREEN BOX is showing you the Gentoo penguin species is the heaviest one in the GRAPH.**

# %%
plt.title("DATA OF PENGUINS")
sns.boxplot(x='species',
            y='body_mass_g',
            hue='species',
            data=pgdata1
            )
# Out:
# <Axes: title={'center': 'DATA OF PENGUINS'}, xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ### **In X= axis, the COUNT plot is showing you different 'penguin' species population and in Y= axis it is showing you that 'Adelie' has big numbers in COUNT plot.**

# %%
plt.title("COUNT PLOT OF SPECIES")
sns.countplot(x="species",data=pgdata1)
plt.show()

# %% [markdown]
# # **USING COUNT PLOT FOR SHOWING YOU THE ACTUAL POPULATION OF DIFFERENT PENGUIN SPECIES IN DIFFERENT ISLANDS**

# %% [markdown]
# ### **In X = axis,the COUNT plot is showing you different types of 'penguin' species with hue(colours) of island,and in Y = axis,it is showing you the total population of all three species in different islands.**
# ### **As you can see the Gentoo penguins species are more in GRAPH at the Biscoe island.**

# %%
plt.title("COUNT PLOT OF SPECIES")
sns.countplot(x="species",hue='island',data=pgdata1)
plt.show()

# %% [markdown]
# # Shapiro Wilk Test
# Test wheather a data sample has a Gaussian distribution.
# ## Assumption:
# 1. Observation in each sample are independent and identically distributed(iid).

# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.8 MB 2.9 MB/s eta 0:00:16
#    ---------------------------------------- 0.3/45.8 MB 4.0 MB/s eta 0:00:12
#    ---------------------------------------- 0.4/45.8 MB 3.6 MB/s eta 0:00:13
#     --------------------------------------- 0.7/45.8 MB 4.2 MB/s eta 0:00:11
#     --------------------------------------- 0.9/45.8 MB 4.6 MB/s eta 0:00:10
#    - -------------------------------------- 1.2/45.8 MB 4.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/45.8 MB 5.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.7/45.8 MB 5.4 MB/s eta 0:00:09
#    - -------------------------------------- 2.0/45.8 MB 5.3 MB/s eta 0:00:09
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pg=sns.load_dataset("penguins")
pg.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.title('Histograph')
pg['body_mass_g'].hist()
# Out:
# <Axes: title={'center': 'Histograph'}>

# %%
plt.title('Histograph')
pg['bill_depth_mm'].hist()
# Out:
# <Axes: title={'center': 'Histograph'}>

# %%
plt.title('Histograph')
pg['bill_length_mm'].hist()
# Out:
# <Axes: title={'center': 'Histograph'}>

# %%
plt.title('Histograph')
pg['flipper_length_mm'].hist()
# Out:
# <Axes: title={'center': 'Histograph'}>

# %% [markdown]
# ## **It is very difficult to understand the histograph of each variance,so here we will take help from boxplot to understand the actual Shapiro Wilk test of penguins statistics.**

# %% [markdown]
# ### Now here you can see the boxplot and shapiro test,both are telling the data of all species veriable(flipper_length_mm) is normal.

# %%
plt.title("BOXPLOT OF PENGUINS")
sns.boxplot(x='species',
            y='flipper_length_mm',
            hue='species',
            data=pg)
# Out:
# <Axes: title={'center': 'BOXPLOT OF PENGUINS'}, xlabel='species', ylabel='flipper_length_mm'>

# %%
from scipy.stats import shapiro
data=[penguins]
stat,p=shapiro(pg['flipper_length_mm'])
print('stat=',stat)
print('p=',p)
if p > 0.05:
    print("The data is normal.")
else:
    print("The data is not normal.")
# Out:
# stat= nan
# p= 1.0
# The data is normal.

# %% [markdown]
# ### This is also normal..

# %%
plt.title("BOXPLOT OF PENGUINS")
sns.boxplot(x='species',
            y='bill_length_mm',
            hue='species',
            data=pg)
# Out:
# <Axes: title={'center': 'BOXPLOT OF PENGUINS'}, xlabel='species', ylabel='bill_length_mm'>

# %%
from scipy.stats import shapiro
data=[penguins]
stat,p=shapiro(pg['bill_length_mm'])
print('stat=',stat)
print('p=',p)
if p > 0.05:
    print("The data is normal.")
else:
    print("The data is not normal.")
# Out:
# stat= nan
# p= 1.0
# The data is normal.

# %% [markdown]
# ### This is also normal..

# %%
plt.title("BOXPLOT OF PENGUINS")
sns.boxplot(x='species',
            y='body_mass_g',
            hue='species',
            data=pg)
# Out:
# <Axes: title={'center': 'BOXPLOT OF PENGUINS'}, xlabel='species', ylabel='body_mass_g'>

# %%
from scipy.stats import shapiro
data=[penguins]
stat,p=shapiro(pg['body_mass_g'])
print('stat=',stat)
print('p=',p)
if p > 0.05:
    print("The data is normal.")
else:
    print("The data is not normal.")
# Out:
# stat= nan
# p= 1.0
# The data is normal.

# %% [markdown]
# # 2.**Correlation Test**
# aage or bhi likhana he

# %%
# pearson's correlation test
from scipy.stats import pearsonr
data=['penguins']
# data2=['bill_length_mm']
pg.dropna()
stat,p=pearsonr(pg['flipper_length_mm'],pg['bill_length_mm'])
print('stat=%.3f,p=%.3f'% (stat,p))
if p>0.05:
    print("Probably independent,(No correlation)")
else:
    print("Probably dependent,(correlation exists)")

# %% [markdown]
# not done will continue later
